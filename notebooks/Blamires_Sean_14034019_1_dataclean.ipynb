# %% [markdown]
# Open libraries

# %%
import numpy as np
import pandas as pd

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Open the training dataset

# %%
path = "C:\\Users\\z3066824\\OneDrive - UNSW\Documents\\"

# %%
file = "train.csv"

# %%
df = pd.read_csv(path+file)

# %%
df
# Out:
#          Id  GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  FTA  \
# 0     10556  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  22.6  ...  2.9
# 1      5342  75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  34.9  ...  3.6
# 2      5716  85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  34.3  ...  0.6
# 3     13790  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  23.7  ...  1.5
# 4      5470  63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  13.7  ...  0.5
# ...     ...  ..   ...   ...  ...  ...   ...      ...  ...   ...  ...  ...
# 7995   2996  32   9.2   1.8  0.7  1.8  40.3     -0.1 -0.2  23.1  ...  0.6
# 7996  11679  54   6.0   1.8  0.7  1.4  48.7      0.1  0.1   3.1  ...  0.4
# 7997   5537  85  28.2  10.7  4.0  9.0  45.1      0.2  0.6  23.6  ...  3.9
# 7998   1292  39   7.7   2.5  1.0  2.3  40.1     -0.3 -0.5  13.3  ...  0.7
# 7999   2900  49  19.2   4.8  1.7  5.1  32.6      0.7  2.4  41.3  ...  1.3
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# ...

# %% [markdown]
# Examine the data

# %%
df.shape
# Out:
# (8000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           8000 non-null   int64
#  1   GP           8000 non-null   int64
#  2   MIN          8000 non-null   float64
#  3   PTS          8000 non-null   float64
#  4   FGM          8000 non-null   float64
#  5   FGA          8000 non-null   float64
#  6   FG%          8000 non-null   float64
#  7   3P Made      8000 non-null   float64
#  8   3PA          8000 non-null   float64
#  9   3P%          8000 non-null   float64
#  10  FTM          8000 non-null   float64
#  11  FTA          8000 non-null   float64
#  12  FT%          8000 non-null   float64
#  13  OREB         8000 non-null   float64
#  14  DREB         8000 non-null   float64
#  15  REB          8000 non-null   float64
#  16  AST          8000 non-null   float64
#  17  STL          8000 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  Id           GP          MIN          PTS          FGM  \
# count   8000.000000  8000.000000  8000.000000  8000.000000  8000.000000
# mean    6856.971000    62.777875    18.576663     7.267087     2.807037
# std     3977.447579    17.118774     8.935263     4.318732     1.693373
# min        4.000000    -8.000000     2.900000     0.800000     0.300000
# 25%     3413.750000    51.000000    12.000000     4.100000     1.600000
# 50%     6787.500000    63.000000    16.800000     6.300000     2.400000
# 75%    10299.250000    74.000000    23.500000     9.500000     3.700000
# max    13798.000000   123.000000    73.800000    34.200000    13.100000
#
#                FGA          FG%      3P Made          3PA          3P%  ...  \
# count  8000.000000  8000.000000  8000.000000  8000.000000  8000.000000  ...
# mean      6.231213    44.608900     0.264525     0.816563    19.583700  ...
# std       3.584559     6.155453     0.384093     1.060964    16.003155  ...
# ...

# %%
df.set_index('Id')
# Out:
#        GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA   3P%  FTM  FTA   FT%  \
# Id
# 10556  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  22.6  2.0  2.9  72.1
# 5342   75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  34.9  2.4  3.6  67.8
# 5716   85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  34.3  0.4  0.6  75.7
# 13790  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  23.7  0.9  1.5  66.9
# 5470   63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  13.7  0.2  0.5  54.0
# ...    ..   ...   ...  ...  ...   ...      ...  ...   ...  ...  ...   ...
# 2996   32   9.2   1.8  0.7  1.8  40.3     -0.1 -0.2  23.1  0.4  0.6  65.7
# 11679  54   6.0   1.8  0.7  1.4  48.7      0.1  0.1   3.1  0.2  0.4  70.1
# 5537   85  28.2  10.7  4.0  9.0  45.1      0.2  0.6  23.6  2.8  3.9  69.7
# 1292   39   7.7   2.5  1.0  2.3  40.1     -0.3 -0.5  13.3  0.6  0.7  74.3
# 2900   49  19.2   4.8  1.7  5.1  32.6      0.7  2.4  41.3  0.8  1.3  70.1
#
#        OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# Id
# ...

# %% [markdown]
# Clean the data and set the variables

# %%
df_cleaned = df.copy()

# %%
df_cleaned.columns = df_cleaned.columns.str.strip()

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
df_cleaned = scaler.fit_transform(df_cleaned)

# %% [markdown]
# Create training and test datasets

# %%
x_train = df.drop(['TARGET_5Yrs'], axis=1)

# %%
x_train
# Out:
#          Id  GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA   3P%  FTM  FTA  \
# 0     10556  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  22.6  2.0  2.9
# 1      5342  75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  34.9  2.4  3.6
# 2      5716  85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  34.3  0.4  0.6
# 3     13790  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  23.7  0.9  1.5
# 4      5470  63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  13.7  0.2  0.5
# ...     ...  ..   ...   ...  ...  ...   ...      ...  ...   ...  ...  ...
# 7995   2996  32   9.2   1.8  0.7  1.8  40.3     -0.1 -0.2  23.1  0.4  0.6
# 7996  11679  54   6.0   1.8  0.7  1.4  48.7      0.1  0.1   3.1  0.2  0.4
# 7997   5537  85  28.2  10.7  4.0  9.0  45.1      0.2  0.6  23.6  2.8  3.9
# 7998   1292  39   7.7   2.5  1.0  2.3  40.1     -0.3 -0.5  13.3  0.6  0.7
# 7999   2900  49  19.2   4.8  1.7  5.1  32.6      0.7  2.4  41.3  0.8  1.3
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV
# ...

# %%
y_train = df['TARGET_5Yrs']

# %%
y_train
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 7995    1
# 7996    1
# 7997    1
# 7998    1
# 7999    1
# Name: TARGET_5Yrs, Length: 8000, dtype: int64

# %%
y_train.shape
# Out:
# (8000,)

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Open the test datset

# %%
file = "test.csv"

# %%
df2 = pd.read_csv(path+file)

# %%
df2
# Out:
#         Id  GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA   3P%  FTM  FTA  \
# 0        1  56   9.1   4.0  1.6   3.7  43.7      0.1  0.3   7.3  0.7  1.2
# 1     8194  43  19.3  10.1  3.7   8.1  46.0      0.6  1.7  35.1  1.8  2.5
# 2        3  82  33.9  11.3  4.9  10.6  45.6      0.5  1.9  44.8  1.8  2.7
# 3     8196  86  44.7  18.8  6.8  15.9  42.9      0.5  1.8  13.5  4.5  6.3
# 4     8197  58  12.3   4.7  1.6   4.0  40.0      0.5  1.7  38.7  1.1  1.3
# ...    ...  ..   ...   ...  ...   ...   ...      ...  ...   ...  ...  ...
# 3794  8175  84  21.2   8.7  3.4   6.7  50.2      0.0  0.0  -4.5  1.7  2.5
# 3795  8176  49  16.3   6.4  2.9   6.6  44.4     -0.1 -0.4  19.8  1.0  1.9
# 3796  8178  53   9.9   2.1  0.8   1.8  43.1     -0.4 -0.6   1.9  0.6  1.0
# 3797  8181  89  38.3  14.5  5.4  11.8  45.2      0.5  1.2  24.7  2.5  2.9
# 3798  8183  55  12.0   3.0  1.1   2.5  42.3      0.1  0.6  11.7  0.9  1.1
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV
# ...

# %%
df2_cleaned = df2.copy()

# %%
df2_cleaned.columns = df2_cleaned.columns.str.strip()

# %%
x_test = df2_cleaned

# %%
x_test
# Out:
#         Id  GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA   3P%  FTM  FTA  \
# 0        1  56   9.1   4.0  1.6   3.7  43.7      0.1  0.3   7.3  0.7  1.2
# 1     8194  43  19.3  10.1  3.7   8.1  46.0      0.6  1.7  35.1  1.8  2.5
# 2        3  82  33.9  11.3  4.9  10.6  45.6      0.5  1.9  44.8  1.8  2.7
# 3     8196  86  44.7  18.8  6.8  15.9  42.9      0.5  1.8  13.5  4.5  6.3
# 4     8197  58  12.3   4.7  1.6   4.0  40.0      0.5  1.7  38.7  1.1  1.3
# ...    ...  ..   ...   ...  ...   ...   ...      ...  ...   ...  ...  ...
# 3794  8175  84  21.2   8.7  3.4   6.7  50.2      0.0  0.0  -4.5  1.7  2.5
# 3795  8176  49  16.3   6.4  2.9   6.6  44.4     -0.1 -0.4  19.8  1.0  1.9
# 3796  8178  53   9.9   2.1  0.8   1.8  43.1     -0.4 -0.6   1.9  0.6  1.0
# 3797  8181  89  38.3  14.5  5.4  11.8  45.2      0.5  1.2  24.7  2.5  2.9
# 3798  8183  55  12.0   3.0  1.1   2.5  42.3      0.1  0.6  11.7  0.9  1.1
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV
# ...

# %% [markdown]
# Build a regression model

# %%
from sklearn.model_selection import train_test_split

# %%
y_test = train_test_split(
    df['TARGET_5Yrs'], test_size=0.2, random_state=42)

# %%
y_test
# Out:
# [1467    1
#  5768    1
#  5714    1
#  1578    1
#  6958    1
#         ..
#  5226    1
#  5390    1
#  860     1
#  7603    1
#  7270    1
#  Name: TARGET_5Yrs, Length: 6400, dtype: int64,
#  2215    1
#  2582    1
#  1662    1
#  3027    1
#  4343    1
#         ..
#  1079    1
#  7979    1
#  1115    1
#  6093    1
#  6832    1
#  Name: TARGET_5Yrs, Length: 1600, dtype: int64]

# %%
y_test = pd.Series(y_test)

# %%
type(y_test)
# Out:
# pandas.core.series.Series

# %%
y_test
# Out:
# 0    1467    1
# 5768    1
# 5714    1
# 1578    1
# 6958  ...
# 1    2215    1
# 2582    1
# 1662    1
# 3027    1
# 4343  ...
# dtype: object

# %%
y_test.shape
# Out:
# (2,)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_lr_train_pred = lr.predict(x_train)
y_lr_test_pred = lr.predict(x_test)

# %% [markdown]
# Assess model comparing training and test SME

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
lr_train_mse = mean_squared_error(y_train, y_lr_train_pred)

# %%
lr_train_mse
# Out:
# 0.12818585013890255

# %%
lr_test_mse = mean_squared_error(y_train[:3799], y_lr_test_pred)

# %%
lr_test_mse
# Out:
# 0.15222451020970168

# %%
lr_train_r2 = r2_score(y_train, y_lr_train_pred)

# %%
lr_train_r2
# Out:
# 0.07576738724957566

# %%
lr_results = pd.DataFrame(['Linear regression',lr_train_mse, lr_train_r2, lr_test_mse]).transpose()

# %%
lr_results.columns = ['Method','Training MSE','Training R2', 'Test MSE']

# %%
lr_results
# Out:
#               Method Training MSE Training R2  Test MSE
# 0  Linear regression     0.128186    0.075767  0.152225

# %% [markdown]
# Similar SMEs indicates validated the test model. Regression between test and training data is poor at 0.07

# %% [markdown]
# Send outputs to files?

# %%
from joblib import dump
