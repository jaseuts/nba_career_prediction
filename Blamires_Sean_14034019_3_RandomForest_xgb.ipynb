# %% [markdown]
# Load libraries and data

# %%
import numpy as np
import pandas as pd

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

# %%
path = "C:\\Users\\z3066824\\OneDrive - UNSW\Documents\\"

# %%
file = "train.csv"

# %%
df = pd.read_csv(path+file)

# %%
df
# Out:
#          Id  GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  FTA  \
# 0     10556  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  22.6  ...  2.9
# 1      5342  75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  34.9  ...  3.6
# 2      5716  85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  34.3  ...  0.6
# 3     13790  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  23.7  ...  1.5
# 4      5470  63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  13.7  ...  0.5
# ...     ...  ..   ...   ...  ...  ...   ...      ...  ...   ...  ...  ...
# 7995   2996  32   9.2   1.8  0.7  1.8  40.3     -0.1 -0.2  23.1  ...  0.6
# 7996  11679  54   6.0   1.8  0.7  1.4  48.7      0.1  0.1   3.1  ...  0.4
# 7997   5537  85  28.2  10.7  4.0  9.0  45.1      0.2  0.6  23.6  ...  3.9
# 7998   1292  39   7.7   2.5  1.0  2.3  40.1     -0.3 -0.5  13.3  ...  0.7
# 7999   2900  49  19.2   4.8  1.7  5.1  32.6      0.7  2.4  41.3  ...  1.3
#
#        FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# ...

# %%
df.columns
# Out:
# Index(['Id', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3P Made', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV',
#        'TARGET_5Yrs'],
#       dtype='object')

# %%
df.shape
# Out:
# (8000, 21)

# %%
df.set_index('Id')
# Out:
#        GP   MIN   PTS  FGM  FGA   FG%  3P Made  3PA   3P%  FTM  FTA   FT%  \
# Id
# 10556  80  24.3   7.8  3.0  6.4  45.7      0.1  0.3  22.6  2.0  2.9  72.1
# 5342   75  21.8  10.5  4.2  7.9  55.1     -0.3 -1.0  34.9  2.4  3.6  67.8
# 5716   85  19.1   4.5  1.9  4.5  42.8      0.4  1.2  34.3  0.4  0.6  75.7
# 13790  63  19.1   8.2  3.5  6.7  52.5      0.3  0.8  23.7  0.9  1.5  66.9
# 5470   63  17.8   3.7  1.7  3.4  50.8      0.5  1.4  13.7  0.2  0.5  54.0
# ...    ..   ...   ...  ...  ...   ...      ...  ...   ...  ...  ...   ...
# 2996   32   9.2   1.8  0.7  1.8  40.3     -0.1 -0.2  23.1  0.4  0.6  65.7
# 11679  54   6.0   1.8  0.7  1.4  48.7      0.1  0.1   3.1  0.2  0.4  70.1
# 5537   85  28.2  10.7  4.0  9.0  45.1      0.2  0.6  23.6  2.8  3.9  69.7
# 1292   39   7.7   2.5  1.0  2.3  40.1     -0.3 -0.5  13.3  0.6  0.7  74.3
# 2900   49  19.2   4.8  1.7  5.1  32.6      0.7  2.4  41.3  0.8  1.3  70.1
#
#        OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# Id
# ...

# %% [markdown]
# Define X and y and solit the training and testing data

# %%
X = df.iloc[:, 0:20].values
y = df.iloc[:, 20].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state = 0)

# %% [raw]
# Build the Random Forest Model and predict on y

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
regressor = RandomForestRegressor(n_estimators = 20, random_state = 0)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
y_pred
# Out:
# array([0.9 , 0.7 , 0.95, ..., 1.  , 0.85, 0.85])

# %% [markdown]
# Check the accuracy of the model

# %%
print ('Mean Absolute Error:', metrics.mean_absolute_error (y_test, y_pred))
# Out:
# Mean Absolute Error: 0.26670000000000005

# %%
print ('Mean Squared Error:', metrics.mean_squared_error (y_test, y_pred))
# Out:
# Mean Squared Error: 0.13858249999999997

# %%
print ('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error (y_test, y_pred)))
# Out:
# Root Mean Squared Error: 0.3722667054680018

# %% [markdown]
# Determine confusion matrix and accuracy score

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
r_f = RandomForestRegressor(n_estimators = 1, random_state = 0)

# %%
r_f.fit(X_train, y_train)
y_pred2 = r_f.predict(X_test)
y_pred2
# Out:
# array([1., 1., 1., ..., 1., 0., 1.])

# %%
print(confusion_matrix(y_test, y_pred2))
print(accuracy_score(y_test, y_pred2))
# Out:
# [[  99  235]
#  [ 293 1373]]
# 0.736

# %% [markdown]
# Create csv of preditions

# %%
pd.DataFrame(y_pred2).to_csv("C:\\Users\\z3066824\\OneDrive - UNSW\Documents\\Blamires_Sean.csv")

# %% [markdown]
# Check model performance using gradient boosting

# %%
pip install xgboost

# %%
import xgboost as xgb
# Out:
# C:\Users\z3066824\Anaconda3\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
xgboost1 = xgb.XGBClassifier()

# %%
xgboost1.fit(X_train, y_train)
# Out:
# C:\Users\z3066824\Anaconda3\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [14:42:42] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, importance_type=None,
# ...

# %% [markdown]
# Use joblib to dump and save the the model fitted

# %%
from joblib import dump

# %%
dump(xgboost1,  'C:\\Users\\z3066824\\OneDrive - UNSW\Documents\\xgboost_default.joblib')
# Out:
# ['C:\\Users\\z3066824\\OneDrive - UNSW\\Documents\\xgboost_default.joblib']

# %% [markdown]
# Estimate Accuracy and validate

# %%
y_train_preds = xgboost1.predict(X_train)
y_val_preds = xgboost1.predict(X_test)

# %%
def print_class_perf(y_preds, y_actuals, set_name=None, average='binary'):
    
    from sklearn.metrics import accuracy_score
    from sklearn.metrics import f1_score

    print(f"Accuracy {set_name}: {accuracy_score(y_actuals, y_preds)}")
    print(f"F1 {set_name}: {f1_score(y_actuals, y_preds, average=average)}")

# %%
print_class_perf(y_preds=y_train_preds, y_actuals=y_train, set_name='Training', average='weighted')
print_class_perf(y_preds=y_test, y_actuals=y_test, set_name='Validation', average='weighted')
# Out:
# Accuracy Training: 0.9831666666666666
# F1 Training: 0.9828017083032995
# Accuracy Validation: 1.0
# F1 Validation: 1.0
